# %%
#Take a string from user and replace all spaces with underscore _ using replace() method.

a=input()
print(a.replace(" ","-"))
# Out:
#  akshitha amarendhar marri
# akshitha-amarendhar-marri

# %%
#Take any string and remove leading and trailing spaces using strip().
a="    Akshitha     "
print(a.strip())
print(a.lstrip())
print(a.rstrip())
# Out:
# Akshitha
# Akshitha
#     Akshitha

# %%
#Take a sentence and check whether it starts with "Hello" using startswith().
a=" akshitha "
print(a.startswith("hello"))
# Out:
# False

# %%
#Take a string and check if it ends with ".com" using endswith().
a="akshitha@gmail.com"
print(a.endswith(".com"))
# Out:
# True

# %%
b="apple,banana,mango"
print(b.split())
# Out:
# ['apple,banana,mango']

# %%
a=["apple","banana","mango","grapes","papaya"]
print(" ".join(a))
# Out:
# apple banana mango grapes papaya

# %%
list= [" Python ", " is ", " awesome "]
list[0]=list[0].strip()
list[1]=list[1].strip()
list[2]=list[2].strip()

# %%
# it gives the o/p in the stream
list= [" Python ", " is ", " awesome "]
list[0].strip() + " " + list[1].strip() + " " + list[2].strip()
("".join(list))
# Out:
# ' Python  is  awesome '

# %%
# it gives the o/p as the list
list= [" Python ", " is ", " awesome "]
list[0]=list[0].strip()
list[1]=list[1].strip()
list[2]=list[2].strip()

# %%
a="Akshitha Marri"
b=a.split(" ")
print(b[0])
print(b[1])
# Out:
# Akshitha
# Marri

# %%
a=input()
b=a.split(" ")
print(b)
print(len(b))
# Out:
#  my name is akshitha
# ['my', 'name', 'is', 'akshitha']
# 4

# %%
a="akshitha@gmail.com"
print(a.endswith("@gmail.com"))
# Out:
# True

# %%
a="Hello World Python"
b=(a.replace("World","Everyone"))
print(b)
c=b.split()
print(c)
# Out:
# Hello Everyone Python
# ['Hello', 'Everyone', 'Python']

# %%
a="hello world"
b=(a.title())
print(b)
print(b.startswith("Hello"))
# Out:
# Hello World
# True

# %%
a="I am bad"
b=a.split()
(" ".join(b))
b=a.replace("bad","good")
print(b)
# Out:
# I am good

# %%
list = ["10", "20", "30", "40"]
("-".join(list))
# Out:
# '10-20-30-40'

# %%
a="sumathi reddy institute of technology for women"
b=(a.startswith("a"))
c=(a.startswith("e"))
d=(a.startswith("i"))
e=(a.startswith("o"))
f=(a.startswith("u"))



print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# False
# False
# False
# False
# False

# %%
a="my name is akshitha"
b=a.replace(" ","-")
print(b)
c=b.split("-")
print(c)
print(len(c))
if len(c[0])>4:
    print(c[0])
elif len(c[1])>4:
    print(c[1])
elif len(c[2])>4:
    print(c[2])
elif len(c[3])>4:
    print(c[3])
elif len(c[4])>4:
    print(c[4])
# Out:
# my-name-is-akshitha
# ['my', 'name', 'is', 'akshitha']
# 4
# akshitha

# %%
names=["Haritha","Varshini","Akshitha","Siri","Minnu"]
((" , ").join(names))
names[0]="Tejeswini"
print(names)
# Out:
# ['Tejeswini', 'Varshini', 'Akshitha', 'Siri', 'Minnu']

# %%
cities=[]
for i in range(5):
    city=input(f" Enter city {i+1}:")
    cities.append(city)
print("\n City names")
print("\n".join(cities))
# Out:
#  Enter city 1: hyderabad
#  Enter city 2: warangal
#  Enter city 3: hanamkonda
#  Enter city 4: karimnagar
#  Enter city 5: Sricilla
#  City names
# hyderabad
# warangal
# hanamkonda
# karimnagar
# Sricilla

# %%
paragraph=
