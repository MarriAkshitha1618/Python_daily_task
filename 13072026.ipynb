# %%
a=int(input())
if a>0:
    if a%2==0:
        print("Even")
        print("Positive")
    else:
        print("Odd")
else:
    print("Negative")
# Out:
#  21
# Odd

# %%
age=int(input())
if age>=18:
    if age>=60:
        print("Senior Citizen")
    else:
        print("Adult")
else:
    print("not valid")
# Out:
#  60
# Senior Citizen

# %%
char=input()
if char.isalpha():
    if char.isupper():
        print("Uppercase")
    else:
        print("Lowercase")
else:
    print("not a character")
# Out:
#  T
# Uppercase

# %%
a=10
b=20
c=30
if a>b:
    if a>c:
        print("C is greater")
    else:
        print("A is greater")
else:
    if b>c:
        print("B is greater")
    else:
        print("C is greater")
# Out:
# C is greater

# %%
marks=int(input())
if marks>=40:
    if marks>=75:
        print("Pass with Distinction")
    else:
        print("Pass")
else:
    print("Fail")
# Out:
#  90
# Pass with Distinction

# %%
a=int(input())
if a%2==0:
    if a%4==0:
        print("Divisible by 4")
    else:
        print("Divisible by 2")
else:
    print("Not divisible")
# Out:
#  8
# Divisible by 4

# %%
username="admin"
user_name=input()
if username==user_name:
    password=1234
    password_ip=int(input())
    if password==password_ip:
        print("passord correct")
    else:
        print("password incorrect")
else:
    print("invalid username")
# Out:
#  admin
#  1234
# passord correct

# %%
a=int(input())
b=int(input())
c=int(input())
if a+b>c or a+c>b or b+a>c:
    if a==b==c:
        print("Equilateral")
        print("Valid traingle")
    elif a==b!=c:
        print("Isosceles")
        print("Valid traingle")
    elif a!=b==c:
        print("Scalene")
        print("Valid traingle")
    else:
        print("not shows this properties")
else:
    print("Invalid traingle")
# Out:
#  20
#  20
#  40
# Isosceles
# Valid traingle

# %%
salary=int(input())
experience=float(input())
if salary>=50000:
    if experience>=3.5:
        print("Senior Manager")
    else:
        print("Manager")
else:
    print("Less salary")
# Out:
#  60000
#  4
# Senior Manager

# %%
char=input()
if char.isalpha():
    if char=='a' or char=='e' or char=='i' or char=='o' or char=='u':
        print("Vowel")
    else:
        print("Consonant")
else:
    if char.isdigit():
        print("Digit")
    else:
        print("Special character")
# Out:
#  @
# Special character

# %%
year=int(input())
if year>=0:
    if (year%4==0 and year%100!=0) or year%400==0:
        print("Leap year")
    else:
        print("Not a leap year")
else:
    print("Not a valid year")
# Out:
#  1998
# Not a leap year

# %%
temp=int(input())
if temp>30:
    if 20<=temp<=30:
    
       print("Warm")
    else:
         print("Hot")
else:
    print("Cold")
# Out:
#  2
# Cold

# %%
a=int(input())
b=int(input())
c=int(input())
if a==b:
    if b==c:
        print("three are equal")
    else:
        print("two are equal")
else:
    if a==c:
        print("two are equal")
    elif b==c:
            print("two are equal")
    else:
        print("All are different")
# Out:
#  10
#  20
#  30
# All are different

# %%
num=int(input())
if num>0:
    if num%2==0:
        print("Positive Even Number")
    else:
        print("Positive Odd number")
else:
    print("Negative number")
# Out:
#  21
# Positive Odd number

# %%
a1=int(input())
a2=int(input())
a3=int(input())
a4=int(input())
a5=int(input())
avg=(a1+a2+a3+a4+a5)/5
print(f"{avg}")
if avg>=60:
    if ((a1>=40) and (a2>=40) and (a3>=40) and  (a4>=40) and (a5>=40)):
        print("good avg")
    else:
        if avg<40:
            print("fail")
else:
     print("Distinction marks")
# Out:
#  90
#  99
#  98
#  99
#  98
# 96.8
# good avg

# %%
username="admin"
password=1234
user_name=input()
password1=int(input())
age=int(input())
if username==user_name:
    if password==password1:
        if age>=18:
            print("Login successful")
        else:
            print("Age ristriction")
    else:
        print("Invalid password")
else:
    print("Invalid username")
# Out:
#  admin
#  1234
#  18
# Login successful

# %%
num=int(input())
if num%3==0:
    if num%5==0:
        print("Divisible by 3 and 5")
    else:
        print("Divisible by 3")
else:
    print("not divisible ")
# Out:
#  15
# Divisible by 3 and 5

# %%
a=int(input())
b=int(input())
c=int(input())
if a+b>c or a+c>b or b+c<a:
    if ((a**a)==((b**b)+(c**c))):
        print("right-angled triangle")
    else:
        print("not a right angle triangle")
else:
    print("Invalid triangle")
# Out:
#  2
#  3
#  5
# not a right angle triangle

# %%
a1=input()
if a1=='A':
    print("Excellent")
elif a1=='B':
    print("Good")
elif a1=='C':
    print("Average")
elif a1=="D":
    print("clear")
elif a=="E":
    print("pass")
else:
    print("Invalid")
# Out:
#  C
# Average

# %%
Income=int(input())
if Income>1000000:
    print("High Income")
    if Income <= 2000000:
        print("Tax slab: 20%")
    elif Income <=3000000:
        print("Tax slab: 30%")
    elif Income <=4000000:
        print("Tax slab: 35%")
    elif Income <=5000000:
        print("Tax slab:40%")
    else:
        print("Medium Income")
else:
    print("Low Income")
# Out:
#  1000000
# Low Income

# %%
a=int(input())
b=int(input())
c=int(input())
if a+b>c or a+c>b or b+c>a:
    if a==b==c:
        print("Equilateral")
        print("valid traingle")
    elif a==b!=c:
        print("Isosceles")
        print("valid traingle")
    elif a!=b==c:
        print("Scalene")
        print("valid traingle")
    else:
        print("Not form traingle")
        
else:
    print("Invalid traingle")
# Out:
#  10
#  20
#  20
# Scalene
# valid traingle

# %%
s1=int(input())
s2=int(input())
s3=int(input())
s4=int(input())
s5=int(input())
avg=(s1+s2+s3+s4+s5)/5
print(f"{avg}")
if avg>=60:
    if (s1>=40) and (s2>=40) and (s3>=40) and (s4>=40) and (s5>=40):
        print("Pass with Good Performance")
    else:
        print("Pass but Weak in some subjects")
else:
    print("Fail")
# Out:
#  45
#  87
#  90
#  98
#  99
# 83.8
# Pass with Good Performance

# %%
user_name=input()
password_ip=input()
age=int(input())
username="admin"
password="python123"
if age < 18:
    print("You are too young to login")
else:
    if user_name!=username:
        print("Invalid Username")
    elif password_ip!=password:
        print("Invalid password")
    else:
        print("Login successful")
# Out:
#  admin
#  python123
#  18
# Login successful

# %%
user_name=input()
password_ip=input()
age=int(input())
username="admin"
password="python123"
if age>=18:
    if password==password_ip and user_name==username:
        print("Login successful")
    elif password!=password:
        print("Invalid password")
    elif user_name!=username:
        print("Invalid username")
else:
    print("You are too young to long")
# Out:
#  admin
#  python123
#  16
# You are too young to long

# %%
num=int(input())
if num>0:
    print("positive")
    if num%3==0 and num%5==0:
        print("FizzBuzz")
    elif num%3==0:
        print("Fizz")
    elif num%5==0:
        print("Buzz")
else:
    print("Negative")
# Out:
#  12
# positive
# Fizz

# %%
a=int(input())
b=int(input())
c=int(input())
if a==b:
    if b==c:
        print("Three are equal")
    else:
        if a>=b and a>=c:
            largest=a
        elif b>a and b>c:
            largest=b
        else:
            largest=c
        print(f"the largest number is :{largest}")
        if largest%2==0:
            print(f"The largest number {largest} is even")
        else:
            print(f"The largest number {largest} is odd")
# Out:
#  10
#  20
#  30
