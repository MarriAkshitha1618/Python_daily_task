# %%
age = int(input(""))
marks=int(input(""))
if 18 <= age <= 25 and marks >=60:
    print("Eligilble for Admission")
else:
    print("Not Eligilble for Admission")
# Out:
#  18
#  68
# Eligilble for Admission

# %%
username=input()
password=input()

if username=="admin" and password=="12345":
    print("Login Successful")
else:
    print("Login failed")
# Out:
#  admin
#  12345
# Login Successful

# %%
a=int(input())
if 50 <= a <=100 and (a%5!=0):
    print(" not divisible")
else:
    print("divisible")
# Out:
#  56
#  not divisible

# %%
a = int(input("a: "))
b = int(input("b: "))
c = int(input("c: "))
if a>b and a>c:
    print("a is greatest",a)
elif b>a and b>c:
    print("b is greatest",b)
else:
    print("c is greatest",c)
# Out:
# a:  10
# b:  25
# c:  23
# b is greatest 25

# %%
name=input()
print(name)
print(name.upper())
print(name.lower())
print(len(name))
print(name[:3])
print(name[-3:])
# Out:
#  Akshitha
# Akshitha
# AKSHITHA
# akshitha
# 8
# Aks
# tha

# %%
sentence=input()
print(sentence)
print(sentence[:11])
print(sentence[-11:])
print(sentence[5:16])
print(sentence[2])
# Out:
#  honesty is the best  policy
# honesty is the best  policy
# honesty is
# est  policy
# ty is the b
# n

# %%
a=input()
b=a[::-1]
if a==b:
    print("palindrome")
else:
    print("Not a palindrome")
# Out:
#  madam
# palindrome

# %%
a=input()
parts=a.split("@")
print(parts[0])
print(parts[1])
# Out:
#  akshitha@gmail.com
# akshitha
# gmail.com

# %%
password=input()
if (len(password)>=8) and ("@" in password or "#" in password):
    print("strong password")
else:
    print("weak password")
# Out:
#  akshi@123
# strong password

# %%
s1=int(input())
s2=int(input())
s3=int(input())
if s1>=40 and s2>=40 and s3>=40:
    print("pass")
else:
    print("fail")
# Out:
#  45
#  90
#  80
# pass

# %%
a='1234567890'
print(a[:3])
print(a[3:6])
print(a[6:])
# Out:
# 123
# 456
# 7890

# %%
a=int(input())
if a>0 and a%2==0:
    print("even")
elif a<0 or a%2!=0:
    print("odd")
# Out:
#  5
# odd

# %%
city="Hyderabad"
a=city[::-1]
print(a)
count=(city.count("a"))+(city.count("e"))+(city.count("i"))+(city.count("o"))+(city.count("u"))
print(count)
print(city[1:8])
# Out:
# dabaredyH
# 3
# yderaba

# %%
a="9000128607"
print(a[:3])
print(a[-4:])
print(a[3:6])
# Out:
# 900
# 8607
# 012

# %%
a=input()
if len(a)>5 and a.startswith("A") or a.endswith("a"):
    print("Valid string")
else:
    print("Invalid")
# Out:
#  Akshitha
# Valid string
