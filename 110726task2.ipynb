# %%
n=int(input())
if 80 <= n >= 90:
    print("Excellent result")
elif 70 <= n >= 80:
    print("Average result")
elif 45 <= n >= 70:
    print("pass result")
else:
    print("fail ")
# Out:
#  36
# fail

# %%
a=int(input())
if a>0:
    print("Positive")
elif a<0:
    print("Negative")
else:
    print("Zero")
# Out:
#  2
# Positive

# %%
age=int(input())
if age>=18:
    print(f" he can enter in movie,because he is {age}")
else:
    print("cannot enter")
# Out:
#  19
#  he can enter in movie,because he is 19

# %%
a=int(input())
if a%2==0:
    print("Number divisible by 2")
else:
    print("Cannot divide by 2")
# Out:
#  21
# Cannot divide by 2

# %%
a=int(input())
b=int(input())
if a>b:
    print(f" the greatest value is {a}")
else:
    print(f" the greatest value is {b}")
# Out:
#  21
#  5
#  the greatest value is 21

# %%
a=input()
if a.islower():
    print("it is lowercase")
elif a.isupper():
    print("It is uppercase")
# Out:
#  A
# It is uppercase

# %%
a=int(input())
if (a%4==0 and a%100!=0) or a%400==0:
    print("Leap year")
else:
    print("Not a leap year")
# Out:
#  1998
# Not a leap year

# %%
time=int(input()) 
if time<12: 
    print("Morning")
elif 12 <= time <=17:
    print("afternoon")
else:
    print("evening")
# Out:
#  16
# afternoon

# %%
a=int(input())
if a>=75:
    print("Distinction")
elif 35 <= a <=74:
    print("Pass")
else:
    print("fail")
# Out:
#  98
# Distinction

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
    print(f" The greatest value is {a}")
elif b>a and b>c:
    print(f" The greatest value is {b}")
elif c>a and c>b:
    print(f"The greatest value is {c}")
# Out:
#  5
#  98
#  21
#  The greatest value is 98

# %%
units=int(input("Enter the units: "))
if units <100:
    total=2* units
elif  100 < units <= 300:
    total = 4*units
    
elif units >300:
    total=6*units
print(f"The total bill is {total}")
# Out:
# Enter the units:  98
# The total bill is 196

# %%
side1=int(input())
side2=int(input())
side3=int(input())
if side1==side2==side3:
    print("Equilateral")
elif (side1==side2!=side3):
    print("Isosceles")
elif side1!=side2!=side3:
    print("Scalene")
# Out:
#  12
#  13
#  14
# Scalene

# %%
salary=int(input())
if salary>50000:
    total=salary*(20/100)
elif 30000<= salary<=50000:
    total=salary*(10/100)
else:
    total=salary*(5/100)
print(f" the total bonus : {total}")
# Out:
#  60000
#  the total bonus : 12000.0

# %%
username_input="akshitha"
password_input="S143S"
username=input()
password=input()
if username==username_input and password==password_input:
    print("Login successful")
elif username!=username_input and password!=password_input:
    print("Login unsuccessful Wrong password")
elif username==username_input and password!=password_input:
    print("Invalid details")
elif username!=username_input and password==password_input:
    print("Wrong username")
# Out:
#  akshitha
#  S143S
# Login successful

# %%
n=int(input())
if n%3==0 and n%5==0:
    print("Multiple of both 3 and 5")
elif n%3==0:
    print("Multiple of only 3")
elif n%5==0:
    print("Multiple of only 5")
else:
    print("None")
# Out:
#  35
# Multiple of only 5

# %%
person=int(input())
if person<=12:
    print("Child")
elif 13 <= person <=19:
    print("Teenager")
elif 20 <= person <=59:
    print("Adult")
elif person>=60:
    print("Senior Citizen")
# Out:
#  19
# Teenager

# %%
age=int(input())
if age<=5:
    print("Free")
elif 5<= age <=18:
    print("100")
elif age>=19:
    print("200")
elif age>=60:
    print("150")
# Out:
#  18
# 100

# %%
balance=int(input())
choice=int(input("enter choice"))
if choice==1:
    print("balance amount")
elif choice==2:
    amount=int(input())
    if amount<=balance:
        balance=balance-amount
        print("remaining balance",balance)
    else:
        print("no suff")
elif choice==3:
    amount=int(input())
    balance=balance+amount
    print("balance",balance)
else:
    print("invalid")
# Out:
#  10000
# enter choice 2
#  2000
# remaining balance 8000

# %%
income=int(input())
if income < 250000:
    print("No tax")
elif 250000 <= income <= 500000:
    tax=income*(5/100)
elif 500000 <= income <= 1000000:
    tax=income*(20/100)
elif income >= 10000000:
    tax=income*(30/100)
print(f" the tax is {tax}")
# Out:
#  250000
#  the tax is 12500.0

# %%
a=int(input())
b=int(input())
c=int(input())
d=b**2 - 4*a*c
if d>0:
    print("two distinct real roots")
elif d==0:
    print("two equal real roots")
else:
    print("two imaginary roots")
# Out:
#  1
#  2
#  3
# two imaginary roots

# %%
a=int(input())
b=int(input())
choice=int(input("enter the choice: "))
if choice==1:
    c=a+b
    print(c)
elif choice==2:
    d=a-b
    print(d)
elif choice==3:
    e=a*b
    print(e)
elif choice==4:
    f=a/b
    print(f)
# Out:
#  10
#  20
# enter the choice:  3
# 200

# %%
a=int(input())
b=int(input())
c=int(input())
if a+b >c or b+c>a or c+a>b:
    print("valid traingle")
else:
    print("in valid")
# Out:
#  20
#  30
#  50
# valid traingle

# %%
month=int(input())
if 1<= month <=3:
    print("winter")
elif 4 <= month <=6:
    print("summer")
elif 7<= month <= 9:
    print("Rainy")
elif 10<= month <=12:
    print("autum")
# Out:
#  2
# winter

# %%
online_shopping=int(input())
if online_shopping >5000:
    discount=online_shopping*(30/100)
elif 2000 <= online_shopping <= 5000:
    discount=online_shopping*(20/100)
elif online_shopping<2000:
    discount=online_shopping*(10/100)
print(f" the online_shopping discount is : {discount} ")
# Out:
#  5000
#  the online_shopping discount is : 1000.0

# %%
marks=int(input())
if marks >=90:
    print("Excellent")
elif 70 <= marks <= 89:
    print("Good")
elif 50 <= marks <= 69:
    print("Average")
elif marks<50:
    print("poor")
# Out:
#  98
# Excellent
