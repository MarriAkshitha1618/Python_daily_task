# %%
square= lambda x: x*x
square(5)
# Out:
# 25

# %%
cube=lambda x: pow(x,3)
cube(4)
# Out:
# 64

# %%
add=lambda x ,y : (x+y)
add(2,3)
# Out:
# 5

# %%
max=lambda x,y: x if x > y else b
max(15,8)
# Out:
# 15

# %%
even_odd= lambda x: "Even" if x%2==0 else "Odd"
even_odd(9)
# Out:
# 'Odd'

# %%
num=[1,2,3,4]
square_map= list(map( lambda x: x*x,num))
print(square_map)
# Out:
# [1, 4, 9, 16]

# %%
num=[1,2,3,4,5,6]
result=list(filter(lambda x: x%2==0,num))
print(result)
# Out:
# [2, 4, 6]

# %%
num=[20,45,55,70]
result=list(filter(lambda x: x>50,num))
print(result)
# Out:
# [55, 70]

# %%
num=[9,5,1,8,2]
result=sorted(num,key=lambda x:x)
print(result)
# Out:
# [1, 2, 5, 8, 9]

# %%
  
num=[9,5,1,8,2]
result=sorted(num,key=lambda x:-x)
print(result)
# Out:
# [9, 8, 5, 2, 1]

# %%
from functools import reduce
num=[10,20,30,40]
result = reduce(lambda x,y: x+y, num)

print(result)
# Out:
# 100

# %%
from functools import reduce
num=[2,3,4,5]
result = reduce(lambda x,y: x*y, num)

print(result)
# Out:
# 120

# %%
students = [
("Ram",22),
("Amit",19),
("Neha",25),
("Raj",20)
]
result= sorted(students,key=lambda x:x[1])
print(result)
# Out:
# [('Amit', 19), ('Raj', 20), ('Ram', 22), ('Neha', 25)]

# %%
 dicts=lambda marks :{


"A":80,
"B":95,
"C":70,
"D":88
}
dicts("marks")
# Out:
# {'A': 80, 'B': 95, 'C': 70, 'D': 88}

# %%
fruits = ["apple", "banana", "kiwi", "watermelon"]

longest = sorted(fruits, key=lambda x: len(x))[-1]
print(longest)
# Out:
# watermelon

# %%
s = [
("Ram",75),
("Amit",90),
("Raj",80)
]
print(max(s, key=lambda x:x[1]))
# Out:
# ('Amit', 90)

# %%
employees = [
("A",35000),
("B",42000),
("C",28000)
]

print(min(employees, key=lambda x:x[1]))
# Out:
# ('C', 28000)

# %%
names=["ram","amit","neha"]
upper = (list(map(lambda s: s.upper(),names)))
print(upper)
# Out:
# ['RAM', 'AMIT', 'NEHA']

# %%
words = ["apple", "banana", "kiwi", "orange", "grapes"]

result = list(filter(lambda word: len(word) > 5, words))

print(result)
# Out:
# ['banana', 'orange', 'grapes']

# %%
tuples = [(1,5), (3,2), (2,8), (4,1)]

sorted_tuples = sorted(tuples, key=lambda x: x[1])

print(sorted_tuples)
# Out:
# [(4, 1), (3, 2), (1, 5), (2, 8)]

# %%
 employees =[
{"name":"Ram","salary":50000},
{"name":"Amit","salary":65000},
{"name":"Neha","salary":45000}
]
result = sorted(employees, key=lambda x:x["salary"])
print(result)
# Out:
# [{'name': 'Neha', 'salary': 45000}, {'name': 'Ram', 'salary': 50000}, {'name': 'Amit', 'salary': 65000}]

# %%
students = [
("Ram",90),
("Amit",90),
("Neha",85),
("Raj",95)
]
result=sorted(students,key=lambda x: x[1])
print(result)
result1=sorted(students,key=lambda x:-x[1])
print(result1)
# Out:
# [('Neha', 85), ('Ram', 90), ('Amit', 90), ('Raj', 95)]
# [('Raj', 95), ('Ram', 90), ('Amit', 90), ('Neha', 85)]

# %%
mul=lambda x: lambda y: x*y
print(mul(5)(10))
# Out:
# 50

# %%
power = lambda exp: lambda base: base ** exp
square = power(2)
print(square(6))
# Out:
# 36

# %%
num=[-5,10,-3,8,0,-1,20]
result=list(filter(lambda x : x>=0 ,num))
print(result)
# Out:
# [10, 8, 0, 20]

# %%
num=[1,2,3,4,5,6]
result=list(map(lambda x: x**2 if x%2!=0 else x,num))
print(result)
# Out:
# [1, 2, 9, 4, 25, 6]

# %%
string=["apple","banana","kiwi","grape"]
result = sorted(string,key=lambda x:x[-1])
print(result)
# Out:
# ['banana', 'apple', 'grape', 'kiwi']

# %%
employees = [
("A",45000),
("B",60000),
("C",52000),
("D",75000)
]
result=sorted(employees,key=lambda x: x[1],reverse=True)
second_highest=result[1]
print(second_highest)
# Out:
# ('B', 60000)

# %%
employees = [
{"name":"Ram","age":25,"salary":50000},
{"name":"Amit","age":25,"salary":60000},
{"name":"Neha","age":23,"salary":45000},
{"name":"Raj","age":27,"salary":55000}
]
result=sorted(employees,key=lambda x : x["age"])
result1=sorted(employees,key=lambda x : -x["salary"])
print(result)
print(result1)
# Out:
# [{'name': 'Neha', 'age': 23, 'salary': 45000}, {'name': 'Ram', 'age': 25, 'salary': 50000}, {'name': 'Amit', 'age': 25, 'salary': 60000}, {'name': 'Raj', 'age': 27, 'salary': 55000}]
# [{'name': 'Amit', 'age': 25, 'salary': 60000}, {'name': 'Raj', 'age': 27, 'salary': 55000}, {'name': 'Ram', 'age': 25, 'salary': 50000}, {'name': 'Neha', 'age': 23, 'salary': 45000}]
