# %%
print("Akshitha Marri")
print("SRITW")
print("CSE")
print("Full Stack Python using GenAI and Agentic AI")
# Out:
# Akshitha Marri
# SRITW
# CSE
# Full Stack Python using GenAI and Agentic AI

# %% [markdown]
# # single line comment

# %%
# Akshitha Marri

# %%
#SRITW

# %%
#CSE

# %%
#Full Stack Python using GenAI and Agentic AI

# %% [markdown]
# #### Multi line comment

# %%
# Akshitha Marri
#SRITW
#CSE
#Full Stack Python using GenAI and Agentic AI

# %% [markdown]
# ## Docs String comments

# %%
"""AkshithaMarri,SRITW,CSE,Full Stack Python using GenAI and Agentic AI"""
# Out:
# 'AkshithaMarri,SRITW,CSE,Full Stack Python using GenAI and Agentic AI'

# %%
if True:
    print("Hello World")
    print("Welcome Python")
# Out:
# Hello World
# Welcome Python

# %%
# Variable declaration
name=input("Enter the string")
print("name")
print(type(name))
age=int(input("Enter the age"))
print("age")
print(type(age))
height=float(input("Enter the height"))
print("height")
print(type(height))
is_student=True
print(is_student)
print(type(is_student))
# Out:
# Enter the string akshitha
# name
# <class 'str'>
# Enter the age 20
# age
# <class 'int'>
# Enter the height 125
# height
# <class 'float'>
# True
# <class 'bool'>

# %%
# Varaiable naming rules
#1st_name (variable name should  not start with numbers)
# we should set it as st1_name
#my name (no spaces should be present)
#myname
#total@amount(no symbols should be present)
#totalamount
#class (no keywords should be decalred as the keywords)
#class1
#MyVar(correct)
#_score(correct)
#99marks 
#marks99

# %%
a=int(input())
b=int(input())
c=a+b
d=a-b
e=a*b
f=a/b
g=a//b
h=a%b
i=a**b
print(c)
print(d)
print(e)
print(f)
print(g)
print(h)
print(i)
# Out:
#  10
#  20
# 30
# -10
# 200
# 0.5
# 0
# 10
# 100000000000000000000

# %%
x=int(input())
y=int(input())
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
# Out:
#  20
#  25
# False
# True
# False
# True
# False
# True

# %%
a=int(input())
a+=20
print(a)
a-=10
print(a)
a*=5
print(a)
a/=2
print(a)
a//=4
print(int(a))
a**=2
print(a)
# Out:
#  10
# 30
# 20
# 100
# 50.0
# 12
# 144.0

# %%
name="college"
def sritw():
    student_name="Akshitha"
    print(name,student_name)
sritw()
# Out:
# college Akshitha

# %%
a=int(input())
b=int(input())
c=a+b
print(c)
# Out:
#  12
#  23
# 35

# %%
a=float(input("Temperature in degree centegrede"))
f=(a*(9/5))+32
print(f)

g=(f-32)*(5/9)
print(g)
# Out:
# Temperature in degree centegrede 23.5
# 74.30000000000001
# 23.500000000000007

# %%
s1=int(input("Enter the subject"))
s2=int(input("Enter the subject"))
s3=int(input("Enter the subject"))
s4=int(input("Enter the subject"))
s5=int(input("Enter the subject"))
total=s1+s2+s3+s4+s5
print(total)
p=total/500
print(p)
g=p*100
print(g)
if g>=90:
    print("A+")
elif g>=80:
    print("A")
elif g>=70:
    print("B")
elif g>=60:
    print("C")
else:
    print("fail")
# Out:
# Enter the subject 34
# Enter the subject 98
# Enter the subject 67
# Enter the subject 98
# Enter the subject 67
# 364
# 0.728
# 72.8
# B

# %%
a=int(input())
b=int(input())
temp=a
a= 
b=temp
print(a)
print(b)
# Out:
#  10
#  20
# 20
# 10

# %%
a=int(input())
b=int(input())
a,b=b,a
print(a)
print(b)
# Out:
#  10
#  20
# 20
# 10

# %%
r=int(input())
pi=3.14
area=pi*(r*r)
print(area)
cum=2*(pi*r)
print(cum)
# Out:
#  23
# 1661.0600000000002
# 144.44

# %%
age=int(input("age"))
salary=float(input("salary")) 
if (18 <= age <= 60 ) and (salary >=25000 ):
    print(" Eligilble for loan")
else:
    print(" not eligible")
# Out:
# age 22
# salary 56000
#  Eligilble for loan

# %%
x=10
print(type(int(x)))
print(type(float(x)))
print(type(str(x)))
print(type(bool(x)))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a=int(input())
b=int(input())
