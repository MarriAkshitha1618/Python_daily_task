# %%
def addition():
    x=10
    y=20
    z=x+y
    print(z)
addition()
# Out:
# 30

# %%
a=int(input())
b=int(input())
c=a+b
d=a-b
e=a*b
f=a/b
g=a//b
h=a**b
i=a%b
print(c)
print(d)
print(e)
print(f)
print(g)
print(h)
print(i)
# Out:
#  20
#  10
# 30
# 10
# 200
# 2.0
# 2
# 10240000000000
# 0

# %%
a=10
a+=20
a
# Out:
# 30

# %%
A=20
A+=a
A
# Out:
# 50

# %%
# in integer it does not show the same value in the same location when we change the value the address of the value can be modified
a=10
print(a)
print(id(a))
a=20
print(a)
print(id(a))
# Out:
# 10
# 140706679761624
# 20
# 140706679761944

# %%
#we can access the local variables locally but the global variables can be accessed both locally and globally
a=30
def addTwo():
    x=10
    y=20
    print(x+y)
    z=a+x
    print(z)
addTwo()
# Out:
# 30
# 40

# %%
a=40
def ADD():
    print(a)
ADD()
# Out:
# 40

# %%
X=10
def too():
    Y=20
    print(X+Y)
z=30
print(X+z)
too()
# Out:
# 40
# 30

# %%
a=5
def mul():
    A=a*a
    print(A)
mul()
# Out:
# 25

# %%
b=5 #global
def mul():
    a=5 #local
    print(a*b)
mul()
# Out:
# 25

# %%
y=10
def at():
    print(y)
    x=20
at()
# Out:
# 10

# %%
a=10
def test():
    #global a
    #print(a)
    a=20
test()
print(a)
# Out:
# 10
